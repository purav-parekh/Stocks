# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/purav parekh/Desktop/College/SEM 6/Data Analytics/BSE_30.csv")
#df = pd.read_csv('BSE_30.csv')

# %%
df.head()
# Out:
#        Symbol       Date        Open        High         Low       Close  \
# 0  ADANIPORTS   5/6/2008  150.000000  153.570007  147.820007  151.149994
# 1  ADANIPORTS   5/7/2008  152.000000  154.460007  150.240005  153.309998
# 2  ADANIPORTS   5/8/2008  152.199997  156.759995  150.199997  155.889999
# 3  ADANIPORTS   5/9/2008  155.000000  160.600006  154.210007  156.520004
# 4  ADANIPORTS  5/12/2008  156.000000  163.479996  151.000000  162.500000
#
#     Adj Close     Volume
# 0  134.313477  1782030.0
# 1  136.232864  1180015.0
# 2  138.525497  1856245.0
# 3  139.085312  3251375.0
# 4  144.399170  5031635.0

# %%
df['Symbol'].value_counts()
# Out:
# INFY          2469
# WIPRO         2469
# ONGC          2469
# KOTAKBANK     2469
# BHARTIARTL    2469
# INDUSINDBK    2469
# HEROMOTOCO    2469
# MARUTI        2469
# M&M           2469
# TATAMOTORS    2469
# HINDUNILVR    2469
# AXISBANK      2469
# RELIANCE      2469
# DRREDDY       2469
# SUNPHARMA     2469
# SBIN          2469
# HDFCBANK      2469
# LT            2469
# ITC           2469
# TCS           2469
# YESBANK       2469
# ICICIBANK     2469
# HDFC          2469
# ASIANPAINT    2469
# ADANIPORTS    2469
# TATASTEEL     2469
# POWERGRID     2469
# BAJAJ-AUTO    2456
# TATAMTRDVR    2345
# COALINDIA     1852
# Name: Symbol, dtype: int64

# %%
plt.subplots(figsize=(10,6))
ax=df['Symbol'].value_counts().plot.barh(width=0.5,color=sns.color_palette('inferno',10))
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
plt.show()

# %%
df[df['Symbol'] == 'AXISBANK'].head()
# Out:
#         Symbol       Date        Open        High         Low       Close  \
# 4938  AXISBANK   5/6/2008  190.000000  190.979996  186.820007  189.570007
# 4939  AXISBANK   5/7/2008  189.410004  189.410004  180.210007  181.429993
# 4940  AXISBANK   5/8/2008  180.199997  181.199997  171.020004  172.669998
# 4941  AXISBANK   5/9/2008  172.399994  175.039993  166.210007  167.259995
# 4942  AXISBANK  5/12/2008  163.000000  176.800003  162.399994  175.440002
#
#        Adj Close     Volume
# 4938  114.078735  1925165.0
# 4939  109.180267  1780340.0
# 4940  103.908707  1232780.0
# 4941  100.653107  2292770.0
# 4942  105.575623  1737700.0

# %%
df_banks=df[df['Symbol'].str.contains('SBIN|AXISBANK|HDFCBANK|ICICIBANK|INDUSINDBANK|KOTAKBANK|YESBANK')]

# %%
df_banks.head()
# Out:
#         Symbol       Date        Open        High         Low       Close  \
# 4938  AXISBANK   5/6/2008  190.000000  190.979996  186.820007  189.570007
# 4939  AXISBANK   5/7/2008  189.410004  189.410004  180.210007  181.429993
# 4940  AXISBANK   5/8/2008  180.199997  181.199997  171.020004  172.669998
# 4941  AXISBANK   5/9/2008  172.399994  175.039993  166.210007  167.259995
# 4942  AXISBANK  5/12/2008  163.000000  176.800003  162.399994  175.440002
#
#        Adj Close     Volume
# 4938  114.078735  1925165.0
# 4939  109.180267  1780340.0
# 4940  103.908707  1232780.0
# 4941  100.653107  2292770.0
# 4942  105.575623  1737700.0

# %%
df_axis=df[df['Symbol'].str.contains('AXISBANK')]
df_sbi=df[df['Symbol'].str.contains('SBIN')]
df_hdfc=df[df['Symbol'].str.contains('HDFCBANK')]
df_icici=df[df['Symbol'].str.contains('ICICIBANK')]
df_ind=df[df['Symbol'].str.contains('INDUSINDBANK')]
df_kotak=df[df['Symbol'].str.contains('KOTAKBANK')]
df_yes=df[df['Symbol'].str.contains('YESBANK')]

# %%
plt.plot(df_axis.Date,df_axis.Close)

# %%
plt.plot(df_axis.Date,df_axis.Close, label='AXISBANK') 
plt.plot(df_sbi.Date,df_sbi.Close,label='SBIN') 
df_yes=df[df['Symbol'].str.contains('YESBANK')]
plt.legend()

# %%
plt.plot(df_sbi.Date,df_sbi.Close,label='SBIN') 
plt.legend()

# %%
plt.plot(df_axis.Date,df_axis.Close, label='AXISBANK') 
plt.plot(df_sbi.Date,df_sbi.Close,label='SBIN') 
plt.plot(df_yes.Date,df_yes.Close,label='YESBANK')
plt.legend()

# %%
plt.plot(df_sbi.Date,df_sbi.Close,label='SBIN') 
plt.plot(df_yes.Date,df_yes.Close,label='YESBANK')
plt.legend()

# %%
plt.plot(df_sbi.Date,df_sbi.Close,label='SBIN') 
plt.plot(df_yes.Date,df_yes.Close,label='YESBANK')
plt.plot(df_hdfc.Date,df_hdfc.Close,label='HDFC')
plt.plot(df_icici.Date,df_icici.Close,label='ICICI')
plt.plot(df_kotak.Date,df_kotak.Close,label='KOTAK')
plt.plot(df_ind.Date,df_ind.Close,label='INDUSIND')
plt.plot(df_axis.Date,df_axis.Close,label='AXISBANK')
plt.legend()

# %%
plt.scatter(df_kotak.Date,df_kotak.Close)

# %%
plt.scatter(df_kotak.Volume,df_kotak.Close)

# %%
plt.plot(df_yes.Close,df_yes.Volume,label='YESBANK')
plt.plot(df_kotak.Close,df_kotak.Volume,label='KOTAK')
plt.legend()

# %%
df_banks.isnull().any()
# Out:
# Symbol       False
# Date         False
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# dtype: bool
